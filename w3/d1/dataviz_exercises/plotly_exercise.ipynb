# %% [markdown]
# ## Plotly Assignment
#
# **Note**: For some of you, plotly go does not display at all in Jupyter Labs. It is a known bug with plotly. If you are using Jupyter Labs for this assignment and the plots are not showing, please switch to Jupyter Notebooks or Google Collab to complete this exercise.

# %%
# import plotly graph objects
import plotly.graph_objs as go

# import pandas
import pandas as pd

import numpy as np

# %% [markdown]
# ### Task 1: Create a scatterplot with a 1000 random data points.
#
# - x-axis values should come from a normal distribution using np.random.randn(1000)
#
# - y-axis values should come from a uniform distribution over [0,1) using np.random.rand(1000)

# %%
# obtain the x and y values:
xvals = np.random.randn(1000)
yvals = np.random.rand(1000)

# %%
# define a data variable
data1 = go.Scatter(x=xvals, y=yvals, mode="markers")

# %%
# define the layout, include a title and axis labels
layout1 = go.Layout(title = "Scatterplot",
                   xaxis = {"title": "x values"},
                   yaxis = {"title": "y values"})

# %%
# Create a fig from the data and layout. Then plot the fig
fig1 = go.Figure(data=data1, layout=layout1)
fig1.show()
# Out:
# <div>                            <div id="bc55fca9-f6d2-4d2a-912d-f1013b56102d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc55fca9-f6d2-4d2a-912d-f1013b56102d")) {                    Plotly.newPlot(                        "bc55fca9-f6d2-4d2a-912d-f1013b56102d",                        [{"mode": "markers", "type": "scatter", "x": [0.7629408977432232, 1.4992158546013679, 1.1720352726482035, 1.7777600375921163, 0.903042436210989, 0.3885449555523779, -0.6655639988599663, 0.2257579757908983, -0.8180988487126987, -0.38710318681032885, 0.1926078180756662, -1.5983071238223459, -1.357525735526411, 0.5607609024170267, 1.0075066403419943, -0.9522979419288868, -0.3719661697903891, 2.292398280075782, -1.075892799843452, 1.1087211737100329, -1.20726190586727
# ...

# %% [markdown]
# -------------
# ### Task 2: Create a stacked bar chart with the data in the link below.
#
# **Note** that the questions appear in the index and should be used for the x-axis, while the responses appear as column labels.
#
# Stretch Task: Create a horizontal bar chart! Use this documentation [here](https://plot.ly/python/horizontal-bar-charts/) for help.

# %%
# load data
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/mocksurvey.csv',index_col=0)

# %%
df.head()
# Out:
#             Strongly Agree  Somewhat Agree  Neutral  Somewhat Disagree  \
# Question 1            0.45            0.25     0.10               0.12
# Question 2            0.12            0.07     0.48               0.18
# Question 3            0.05            0.22     0.19               0.23
#
#             Strongly Disagree
# Question 1               0.08
# Question 2               0.15
# Question 3               0.31

# %%
# create traces using a list comprehension:
traces = [go.Bar(name=col, x=df.index, y=df[col].values) for col in df]

# %%
# create a layout, remember to set the barmode here
layout2 = go.Layout(barmode="stack",
                   title="Stacked Bar Chart",
                   yaxis={"title": "proportion"})

# %%
# create a fig from data & layout, and plot the fig.
fig2 = go.Figure(data=traces, layout=layout2)
fig2.show()
# Out:
# <div>                            <div id="5a602aee-c1a7-4b12-b49d-103870c6e315" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a602aee-c1a7-4b12-b49d-103870c6e315")) {                    Plotly.newPlot(                        "5a602aee-c1a7-4b12-b49d-103870c6e315",                        [{"name": "Strongly Agree", "type": "bar", "x": ["Question 1", "Question 2", "Question 3"], "y": [0.45, 0.12, 0.05]}, {"name": "Somewhat Agree", "type": "bar", "x": ["Question 1", "Question 2", "Question 3"], "y": [0.25, 0.07, 0.22]}, {"name": "Neutral", "type": "bar", "x": ["Question 1", "Question 2", "Question 3"], "y": [0.1, 0.48, 0.19]}, {"name": "Somewhat Disagree", "type": "bar", "x": ["Question 1", "Question 2", "Question 3"], "y": [0.12, 0.18, 0.23]}, {"na
# ...

# %% [markdown]
# -------------
# ### Task 3: Create a histogram that plots the `length` field from dataset below. Set the range from 0 to 1, with a bin size of 0.02.

# %%
# load data
df3 = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/abalone.csv')

# %%
df3.head()
# Out:
#   sex  length  diameter  height  whole_weight  shucked_weight  viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell_weight  rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
# create a data variable:
data3 = go.Histogram(x=df3["length"],
                    xbins=dict(size=0.2),
                    autobinx=False)

# %%
# add a layout
layout3 = go.Layout(title="Histogram")

# %%
# create a fig from data & layout, and plot the fig
fig3 = go.Figure(data=data3, layout=layout3)
fig3.show()
# Out:
# <div>                            <div id="2f7f6cad-434f-4880-a6cf-a6ef8eb4ebd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f7f6cad-434f-4880-a6cf-a6ef8eb4ebd0")) {                    Plotly.newPlot(                        "2f7f6cad-434f-4880-a6cf-a6ef8eb4ebd0",                        [{"autobinx": false, "type": "histogram", "x": [0.455, 0.35, 0.53, 0.44, 0.33, 0.425, 0.53, 0.545, 0.475, 0.55, 0.525, 0.43, 0.49, 0.535, 0.47, 0.5, 0.355, 0.44, 0.365, 0.45, 0.355, 0.38, 0.565, 0.55, 0.615, 0.56, 0.58, 0.59, 0.605, 0.575, 0.58, 0.68, 0.665, 0.68, 0.705, 0.465, 0.54, 0.45, 0.575, 0.355, 0.45, 0.55, 0.24, 0.205, 0.21, 0.39, 0.47, 0.46, 0.325, 0.525, 0.52, 0.4, 0.485, 0.47, 0.405, 0.5, 0.445, 0.47, 0.245, 0.505, 0.45, 0.505, 0.53, 0.425, 0.52, 0.475
# ...
